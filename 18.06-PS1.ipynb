# %%
# Run this cell. Ignore the warnings, they are harmless.
using Homework

# %%
# Run this cell to see your scores.
Homework.progress()

# %% [markdown]
# # Problem 1. Vectors

# %% [markdown]
# **(a) (1 pt) SUM OF VECTORS:** What is the sum V of the twelve unit vectors that go from the center of a clock to the hours 1:00, 2:00, ..., 12:00? Write down your answer as a pair of coordinates, correct up to .01.

# %%
z=[ ? ,  ? ]

# %% [markdown]
# <img src="http://2.bp.blogspot.com/-Y5mnXTd33z0/VDGXB-3qE3I/AAAAAAAASl0/mD1sb0gaLtU/s1600/clock-face-time4.jpg" height=100>
# **(b) (1 pt) (SUBTRACTING VECTORS)** In the sum of vectors above, if the 2:00 vector is removed, you can show that the remaining vectors add to 8:00. This is because subtracting a vector is the same as adding
# <span style="border-bottom: 1px solid black; padding-left: 200px">&nbsp;</span> ? <br>
# Write your answer as a number from 1 through 4 below:<br>
# 1. An Opposite Vector
# 2. An Orthogonal Vector
# 3. A Parallel Vector
# 4. Zero

# %% [markdown]
# **(c) (2 pts) (COMPONENTS)** What are the components of the 2:00 vector, v=cos θ,sin θ?

# %%
v=[  ? , ?  ]

# %% [markdown]
# # Problem 2.  Elimination sometimes breaks down

# %% [markdown]
# **(2 pts)** We would like you to use elimination to solve the following linear system of two equations:
#
# $ax + 3y = −3$
#
# $4x + 6y = 6$

# %% [markdown]
# For which number $a$ does elimination break down permanently?

# %%
a = ?

# %% [markdown]
# For which number $a$ does elimination break down temporarily?

# %%
a = ?

# %% [markdown]
# **(2 pts) SOLVING THE NON-SINGULAR SYSTEM**

# %% [markdown]
# Fix the temporary breakdown above by a row exchange and then solve.
#
# Enter the value of $x$:

# %%
x = ?

# %% [markdown]
# Enter the value of $y$:

# %%
y = ?

# %% [markdown]
# # Problem 3.  Linear Combinations

# %% [markdown]
# **(2 pts)** The column vectors
# $u=(1,1,2)^T,v=(1,2,3)^T,w=(3,5,8)^T$
# are in a plane because w is a linear combination of u and v. <br> If w=au+bv:

# %% [markdown]
# Enter the numerical value of $a$:

# %%
a = ?

# %% [markdown]
# Enter the numerical value of $b$:

# %%
b = ?

# %% [markdown]
# **(2 pts) LINEAR COMBINATIONS 2**
#
# The combination above is unique. However, there is more than one combination of u,v,w that produces z=(0,0,0)<sup>T</sup>. <br> Let us find two of them. First, if $2u+cv+dw=(0,0,0)$

# %% [markdown]
# Enter the numerical value of $c$:

# %%
c = ?

# %% [markdown]
# Enter the numerical value of $d$:

# %%
d = ?

# %% [markdown]
# **(1 pt) LINEAR COMBINATIONS 3**
# Second, $u+cv+dw=(0,0,0)$

# %% [markdown]
# Enter the numerical value of $c$:

# %%
c = ?

# %% [markdown]
# Enter the numerical value of $d$:

# %%
d = ?

# %% [markdown]
# At this point you should note that there are infinite ways to write any vector on that plane as a linear combination of $u,v,w$.<br>
# However, there is no way to do that for any vector outside the plane.

# %% [markdown]
# **(2 pts) LINEAR COMBINATIONS 4**
#
# Think about the vector $b=(1,−1,e)^T$. What is the only possible number e that gives a vector on the plane? <br>
# Enter the numercal value of $e$:

# %%
e = ?

# %% [markdown]
# # Problem 4. ORTHOGONAL VECTORS

# %% [markdown]
# **(2 pts)** Find two vectors $v$ and $w$ that are perpendicular to $(1,0,1)$ and to each other. <br> Enter your answer in the form $[a,b,c]$ (note the square brackets).

# %%
v=[?, ? , ?]

# %%
w=[?, ?, ?]

# %% [markdown]
# **(1 pt)A TASTE OF PROJECTION **
# With $v=\begin{pmatrix} 1, 1\end{pmatrix}$ and $w=(1,5)$, choose a number $c$ so that $w−cv$ is perpendicular to $v$.
#
# Enter the numerical value of $c$:

# %%
c = ?

# %% [markdown]
# # Julia Problem 1: Defining a Variable

# %% [markdown]
# **(1 pt)** In Julia you simply assign a variable to x by simply typing the letter x and specifying what it is equal to.  Ending the assignment with a semicolon suppresses printing.  In the IJulia notebook, you execute a Julia command by typing shift + enter.<br>
#
# Write Julia code that assigns 1234 to the variable x. See what happens if you follow with and without a semicolon.

# %%
x = ?

# %% [markdown]
# # Julia Problem 2: Define a Row Vector

# %% [markdown]
# **(1 pt)** Julia, somewhat like python, and  unlike MATLAB has vectors which are different from 1 x n or n x 1 matrices.
# A row vector is created by placing elements between square brackets with commas separating elements, e.g. `[1,1,2,4,6,3]`
#
# Why does Julia do it this way?  Answer: There are many data science applications where
# one dimensional structures are extremely important.
#
# Write Julia code that creates the vector `y` with values 3, 5, 2 and 1
#
# Julia indicates that the result is a 4-element array of 64 bit integers that is 1-dimensional, in other words, a vector!

# %% [markdown]
# # Julia Problem 3: Define a One Column Matrix (there are no column vectors!)

# %% [markdown]
# (1 pt) In Julia one creates a one column matrix by placing elements between square brackets, with spaces separating elements, and then using apostrophe as a transpose: e.g. [1  1  2]' <br>
#
# What really happens here is that [1 1 2] is a 1x3 two dimensional matrix, and the apostrophe
# turns it into a 3x1 two dimensional matrix.
#
#
# Write Julia code that creates the 5x1 matrix  <table>
# <tr> <th> 1 </th>  </tr>
# <tr> <th> 2 </th> </tr>
# <tr> <th> -1  </th> </tr>
# <tr> <th> 0 </th> </tr>
# <tr> <th> 0 </th></tr>
# </table>

# %% [markdown]
# # Julia Problem 4. Define a Matrix

# %% [markdown]
# (1 pt) In Julia a matrix can be written <br>
# ```
#     [1 2 3
#      4 5 6
#      7 8 9]
# ```

# %% [markdown]
# Write Julia code that creates the 2x2 matrix A=
#      <table>
#      <tr> <th> 8 </th> <th> 4 </th> </tr>
#      <tr> <th> 2 </th> <th> 3 </th> </tr>
#      </table>

# %%
A = ?

# %% [markdown]
# # Julia Problem 5: Solve a Linear System

# %% [markdown]
# **(1 pt)** Solve  Ax=b, where
#
# ```
# A=
#  [ 2  1 -1
#   -1  2 -1
#    0 -1  1]
# ```
#   and
# ```
#   b=[1,2,1]
# ```
#   To solve for x, use the backlash command `x=A\b`

# %%
# You need to run this cell to create variables A and b before answering
A=
 [ 2  1 -1
  -1  2 -1
   0 -1  1]

b=[1,2,1];

# %%
# Write the solution here

# %% [markdown]
# # Julia Problem 6: Plot a Line and Interact with it

# %% [markdown]
# **(1 pt)** Plot the linear function $u(x) = 5 + 3x on 0 ≤ x ≤ 8$
#
# Julia has a number of packages for plotting because different people enjoy plotting in different ways.  We will use the *PyPlot* package from python for plotting, and the julia *Interact* package for interacting.  Some of these commands may not make complete sense yet, but you
# can use these "magic incantations" for many purposes without needing to understand how they work.

# %%
# Execute this cell
using PyPlot    # takes a little time but only needs to be executed once
using Interact  # adds the fun interactive feature
# Out:
# INFO: Loading help data...

# %%
# Execute this cell as well
u(x) = 5 + 3x
range=0:.01:8
f=figure()

@manipulate for x=0:.5:8; withfig(f) do
        plot(range,u(range))
        plot(x,u(x),"o")
        title("x=$x u(x)=$(round(u(x),2))")
   end
end
# Out:
# Slider{Float64}([Input{Float64}] 4.0,"x",4.0,0.0:0.5:8.0)
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fe0c248cd10>)

# %% [markdown]
# Slide $x$ to $6.5$ and observe u(6.5)

# %% [markdown]
# There should be a plot that highlights $x=6.5$.  What is $u(6.5)$?

# %% [markdown]
# # Julia Problem 7. Plot Solutions of Linear Systems

# %% [markdown]
# (1 pt) Consider the linear system for various values of p and q that you can manipulate
#
#
# $x + y = p$
#
# $-x + 3y = q$

# %% [markdown]
# Where is the solution when $p=7$ and $q=1$?

# %%
# Execute the code below
f=figure()
x=-3:7:20
@manipulate for p=0:.5:14,q=0:.5:14; withfig(f) do
        plot(x,p-x)
        plot(x,(q+x)/3)
        plot((3*p-q)/4,  (p+q)/4, "o")
        title("p=$p q=$q")
   end
end
# Out:
# Slider{Float64}([Input{Float64}] 7.0,"p",7.0,0.0:0.5:14.0)
# Slider{Float64}([Input{Float64}] 7.0,"q",7.0,0.0:0.5:14.0)
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fe0ff312bd0>)

# %%
# Obtain the solution when p=7 and q=1 and show the plot
(  ?, ?  )

# %% [markdown]
# # Julia Problem 8. Singular Matrices with no zeros

# %% [markdown]
# **(2 pts)**
# Use the Julia [ones](http://julia.readthedocs.org/en/latest/stdlib/arrays/?highlight=ones#Base.ones) command to create a 100x100 matrix A all of whose entries are the number 1.

# %% [markdown]
# Is this matrix 1. singular or 2. nonsingular.  (Type 1 or 2)

# %%
# Run this cell to see your scores.
Homework.progress()

# %%
# You don't need to run this cell, if not specifically asked to for debugging purposes

Pkg.rm("Homework")
Pkg.clone("git://github.com/shashi/Homework.jl.git")
